# %%
# 创建模拟成绩数据
import pandas as pd
import numpy as np

grades_data = {
    'student_id': [f'S{1000+i}' for i in range(50)],
    'math': [np.clip(np.random.normal(75, 15), 0, 100) for _ in range(50)],
    'physics': [np.clip(np.random.normal(70, 12), 0, 100) for _ in range(50)],
    'class': ['A班' if i<25 else 'B班' for i in range(50)]
}
df = pd.DataFrame(grades_data)
df.to_csv('demo_grades.csv', index=False)

# %%
# 试运行基础分析（在Jupyter中执行）
df.describe().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_bbce1_row0_col0 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_bbce1_row0_col1 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_bbce1_row1_col0 {
#   background-color: #3282be;
#   color: #f1f1f1;
# }
# #T_bbce1_row1_col1, #T_bbce1_row5_col1 {
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# #T_bbce1_row2_col0, #T_bbce1_row2_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_bbce1_row3_col0 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_bbce1_row3_col1 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_bbce1_row4_col0 {
#   background-color: #549fcd;
#   color: #f1f1f1;
# }
# #T_bbce1_row4_col1 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_bbce1_row5_col0 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_bbce1_row6_col0 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
# }
# #T_bbce1_row6_col1 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_bbce1_row7_col0, #T_bbce1_row7_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_bbce1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bbce1_level0_col0" class="col_heading level0 col0" >math</th>
#       <th id="T_bbce1_level0_col1" class="col_heading level0 col1" >physics</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bbce1_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_bbce1_row0_col0" class="data row0 col0" >50.000000</td>
#       <td id="T_bbce1_row0_col1" class="data row0 col1" >50.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bbce1_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_bbce1_row1_col0" class="data row1 col0" >73.787934</td>
#       <td id="T_bbce1_row1_col1" class="data row1 col1" >67.256804</td>
#     </tr>
#     <tr>
#       <th id="T_bbce1_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_bbce1_row2_col0" class="data row2 col0" >16.725634</td>
#       <td id="T_bbce1_row2_col1" class="data row2 col1" >11.612790</td>
#     </tr>
#     <tr>
#       <th id="T_bbce1_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_bbce1_row3_col0" class="data row3 col0" >33.825889</td>
#       <td id="T_bbce1_row3_col1" class="data row3 col1" >42.768796</td>
#     </tr>
#     <tr>
#       <th id="T_bbce1_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_bbce1_row4_col0" class="data row4 col0" >64.182149</td>
#       <td id="T_bbce1_row4_col1" class="data row4 col1" >58.364813</td>
#     </tr>
#     <tr>
#       <th id="T_bbce1_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_bbce1_row5_col0" class="data row5 col0" >71.065236</td>
#       <td id="T_bbce1_row5_col1" class="data row5 col1" >67.061675</td>
#     </tr>
#     <tr>
#       <th id="T_bbce1_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_bbce1_row6_col0" class="data row6 col0" >86.588845</td>
#       <td id="T_bbce1_row6_col1" class="data row6 col1" >76.977838</td>
#     </tr>
#     <tr>
#       <th id="T_bbce1_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_bbce1_row7_col0" class="data row7 col0" >100.000000</td>
#       <td id="T_bbce1_row7_col1" class="data row7 col1" >91.645157</td>
#     </tr>
#   </tbody>
# </table>
